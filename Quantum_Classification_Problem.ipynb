# %% [markdown]
# <a href="https://colab.research.google.com/github/thotapremkumar-tpk/Quantum-Machine-Learning/blob/main/Quantum_Classification_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pennylane

import os
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt

OUTPUT_DIR = "outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)
# Out:
# Collecting pennylane
#   Downloading pennylane-0.45.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.16.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pennylane) (3.6.1)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.18.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Collecting autograd<1.9 (from pennylane)
#   Downloading autograd-1.8.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.4 (from pennylane)
#   Downloading autoray-0.8.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from pennylane) (6.2.6)
# Collecting pennylane-lightning>=0.45 (from pennylane)
#   Downloading pennylane_lightning-0.45.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.32.4)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.12/dist-packages (from pennylane) (0.14.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pennylane) (4.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pennylane) (26.2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.3-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.0.2)
# Requirement already satisfied: gast in /usr/local/lib/python3.12/dist-packages (from pennylane) (0.7.0)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.45->pennylane)
#   Downloading scipy_openblas32-0.3.34.0.0-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (3.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2026.6.17)
# Downloading pennylane-0.45.1-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 63.5 MB/s eta 0:00:00
# Downloading autoray-0.8.4-py3-none-any.whl (937 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 937.5/937.5 kB 53.3 MB/s eta 0:00:00
# Downloading autograd-1.8.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 3.9 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.45.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (25.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 47.9 MB/s eta 0:00:00
# Downloading rustworkx-0.18.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 72.9 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.3-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 kB 16.2 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.34.0.0-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 82.8 MB/s eta 0:00:00
# Installing collected packages: appdirs, scipy-openblas32, rustworkx, diastatic-malt, autoray, autograd, pennylane-lightning, pennylane
#   Attempting uninstall: autograd
#     Found existing installation: autograd 1.9.1
#     Uninstalling autograd-1.9.1:
#       Successfully uninstalled autograd-1.9.1
# Successfully installed appdirs-1.4.4 autograd-1.8.0 autoray-0.8.4 diastatic-malt-2.15.3 pennylane-0.45.1 pennylane-lightning-0.45.0 rustworkx-0.18.1 scipy-openblas32-0.3.34.0.0

# %%
# Fix the random seed so restarts/results are reproducible across runs.
np.random.seed(42)

n_qubits = 4
# n_qubits = 4 because we have exactly 4 input features (4 movie ratings) and
# we're using ONE qubit per feature (angle encoding — see CELL 3).

n_layers = 2
# n_layers = 2 means the variational ansatz (the "trainable" part of the
# circuit) repeats its rotate-then-entangle block twice. More layers = more
# expressive circuit, but also more parameters to train and slower training

dev = qml.device("default.qubit", wires=n_qubits)

# %% [markdown]
# Dataset - updated as large dataset in programmatically generated

# %%
def generate_dataset(n_scifi=30, n_romance=30, seed=7):
    """
    Generate a larger synthetic movie-rating dataset :
      - SciFi fan  : Movie1, Movie2 ~ high (4-5); Movie3, Movie4 ~ low (1-2)
      - Romance fan: Movie1, Movie2 ~ low (1-2);  Movie3, Movie4 ~ high (4-5)

    Returns shuffled (X_raw, y) arrays, X_raw with raw 1-5 ratings.
    """
    rng = np.random.default_rng(seed)
    rows, labels = [], []

    for _ in range(n_scifi):
        m1, m2 = rng.integers(4, 6), rng.integers(4, 6)   # 4 or 5
        m3, m4 = rng.integers(1, 3), rng.integers(1, 3)   # 1 or 2
        rows.append([m1, m2, m3, m4])
        labels.append(0)  # SciFi

    for _ in range(n_romance):
        m1, m2 = rng.integers(1, 3), rng.integers(1, 3)   # 1 or 2
        m3, m4 = rng.integers(4, 6), rng.integers(4, 6)   # 4 or 5
        rows.append([m1, m2, m3, m4])
        labels.append(1)  # Romance

    rows = np.array(rows, dtype=float)
    labels = np.array(labels, dtype=float)

    # Shuffle so SciFi/Romance rows aren't grouped in order (more realistic,
    # and prevents any accidental ordering bias during training).
    idx = rng.permutation(len(rows))
    return rows[idx], labels[idx]


# Generate a larger, balanced dataset: 30 SciFi + 30 Romance = 60 users
# (vs. the original 11 users, 10 SciFi + 1 Romance). Change n_scifi /
# n_romance here to resize the dataset further.
X_raw, Y_data = generate_dataset(n_scifi=30, n_romance=30, seed=7)
X_raw = np.array(X_raw, requires_grad=False)

# Print the generated raw data table so it's always visible in the notebook
# output, not just hidden inside generate_dataset().
print("Generated dataset (User ID | Movie1-4 ratings | Preferred Category):")
print("-" * 70)
print(f"{'ID':>3} | {'M1':>3} {'M2':>3} {'M3':>3} {'M4':>3} | {'Category':>8}")
print("-" * 70)
for i, (row, label) in enumerate(zip(X_raw, Y_data)):
    cat = "Romance" if label == 1 else "SciFi"
    print(f"{i:3d} | {int(row[0]):3d} {int(row[1]):3d} {int(row[2]):3d} {int(row[3]):3d} | {cat:>8}")
print("-" * 70)
print(f"Total users: {len(Y_data)}  |  SciFi: {int(np.sum(Y_data==0))}  |  Romance: {int(np.sum(Y_data==1))}\n")

# ANGLE ENCODING: rotation gates take an angle, not a raw rating, so we
# linearly rescale ratings (1-5) to angles [0, pi]:
#   rating 1 -> angle 0   (qubit stays near |0>)
#   rating 5 -> angle pi  (qubit rotates near |1>)
X_data = (X_raw - 1) / 4 * np.pi
# Out:
# Generated dataset (User ID | Movie1-4 ratings | Preferred Category):
# ----------------------------------------------------------------------
#  ID |  M1  M2  M3  M4 | Category
# ----------------------------------------------------------------------
#   0 |   5   4   1   1 |    SciFi
#   1 |   5   4   2   2 |    SciFi
#   2 |   2   1   5   5 |  Romance
#   3 |   2   1   5   5 |  Romance
#   4 |   2   1   5   5 |  Romance
#   5 |   5   5   1   2 |    SciFi
#   6 |   2   2   5   4 |  Romance
#   7 |   5   4   1   1 |    SciFi
#   8 |   1   2   4   4 |  Romance
#   9 |   1   1   4   5 |  Romance
#  10 |   1   2   4   5 |  Romance
#  11 |   5   5   2   1 |    SciFi
#  12 |   1   2   5   4 |  Romance
#  13 |   1   2   4   5 |  Romance
#  14 |   5   5   1   1 |    SciFi
#  15 |   1   2   4   4 |  Romance
#  16 |   1   2   4   5 |  Romance
#  17 |   1   2   4   5 |  Romance
#  18 |   2   1   4   4 |  Romance
#  19 |   2   2   5   4 |  Romance
#  20 |   5   5   2   1 |    SciFi
#  21 |   4   4   1   2 |    SciFi
#  22 |   2   1   5   4 |  Romance
#  23 |   5   4   1   1 |    SciFi
#  24 |   2   2   4   4 |  Romance
#  25 |   5   5   1   2 |    SciFi
#  26 |   2   2   5   5 |  Romance
#  27 |   1   1   5   4 |  Romance
#  28 |   5   4   1   1 |    SciFi
#  29 |   4   5   2   2 |    SciFi
#  30 |   5   5   2   1 |    SciFi
#  31 |   1   1   5   4 |  Romance
#  32 |   1   1   5   5 |  Romance
#  33 |   4   5   1   1 |    SciFi
#  34 |   4   4   1   2 |    SciFi
#  35 |   4   4   2   1 |    SciFi
#  36 |   5   5   2   2 |    SciFi
#  37 |   5   4   2   2 |    SciFi
#  38 |   4   5   2   2 |    SciFi
#  39 |   1   2   5   5 |  Romance
#  40 |   2   1   4   5 |  Romance
#  41 |   2   1   4   4 |  Romance
#  42 |   4   5   1   1 |    SciFi
#  43 |   2   1   4   5 |  Romance
#  44 |   4   4   1   2 |    SciFi
#  45 |   5   5   2   2 |    SciFi
#  46 |   5   5   1   2 |    SciFi
#  47 |   2   1   5   5 |  Romance
#  48 |   4   4   1   1 |    SciFi
#  49 |   2   1   5   5 |  Romance
#  50 |   2   2   4   4 |  Romance
#  51 |   5   4   1   2 |    SciFi
#  52 |   2   1   5   5 |  Romance
#  53 |   1   2   5   5 |  Romance
#  54 |   5   4   2   1 |    SciFi
#  55 |   1   2   5   4 |  Romance
#  56 |   4   4   2   1 |    SciFi
#  57 |   5   5   2   2 |    SciFi
#  58 |   5   4   2   2 |    SciFi
#  59 |   5   5   1   2 |    SciFi
# ----------------------------------------------------------------------
# Total users: 60  |  SciFi: 30  |  Romance: 30

# %% [markdown]
# Quantum Circuit ( Encoding + Trainable + Measurement)

# %%
@qml.qnode(dev)
def circuit(theta, x):
    for l in range(n_layers):
        # --- 1) Encode this user's ratings into rotation angles ---
        for i in range(n_qubits):
            qml.RY(x[i], wires=i)

        # --- 2) Trainable rotations (the "learned weights") ---
        for i in range(n_qubits):
            qml.RY(theta[l, i, 0], wires=i)
            qml.RZ(theta[l, i, 1], wires=i)

        # --- 3) Entangle all 4 qubits in a ring ---
        for i in range(n_qubits):
            qml.CNOT(wires=[i, (i + 1) % n_qubits])

    # Measure the expectation value of Pauli-Z on qubit 0. This returns a
    # number in [-1, +1]: -1 means qubit 0 is very likely |1>, +1 means very
    # likely |0>. We turn this into a class probability in CELL 4.

    return qml.expval(qml.PauliZ(0))

_placeholder_theta = np.zeros((n_layers, n_qubits, 2), requires_grad=False)
print("Circuit structure (qml.draw), illustrated with untrained parameters:")
print(qml.draw(circuit)(_placeholder_theta, X_data[0]))
print()
# Out:
# Circuit structure (qml.draw), illustrated with untrained parameters:
# 0: ──RY(3.14)──RY(0.00)──RZ(0.00)─╭●───────╭X──RY(3.14)──RY(0.00)──RZ(0.00)─╭●───────╭X─┤  <Z>
# 1: ──RY(2.36)──RY(0.00)──RZ(0.00)─╰X─╭●────│───RY(2.36)──RY(0.00)──RZ(0.00)─╰X─╭●────│──┤
# 2: ──RY(0.00)──RY(0.00)──RZ(0.00)────╰X─╭●─│───RY(0.00)──RY(0.00)──RZ(0.00)────╰X─╭●─│──┤
# 3: ──RY(0.00)──RY(0.00)──RZ(0.00)───────╰X─╰●──RY(0.00)──RY(0.00)──RZ(0.00)───────╰X─╰●─┤

# %% [markdown]
# Turn the circuit's raw output into a probability, define the loss

# %%
def forward(theta, x):
    z = circuit(theta, x)
    p = (1.0 - z) / 2.0
    return np.clip(p, 1e-9, 1 - 1e-9)

# CLASS IMBALANCE HANDLING:
# The dataset has 10 SciFi vs 1 Romance example. Without correction, a model
# that always predicts "SciFi" would already score 10/11 = 91% accuracy while
# learning nothing useful. pos_weight scales up the loss contribution of the
# single Romance example (~10x) so misclassifying it is penalized as heavily
# as misclassifying all 10 SciFi examples combined.

pos_weight = np.sum(Y_data == 0) / np.sum(Y_data == 1)  # class-imbalance weight (~10.0)

# %%
def bce_loss(theta, X, Y):
    total = 0.0
    for x, y in zip(X, Y):
        p = forward(theta, x)
        w = float(pos_weight) if y == 1 else 1.0
        total += -w * (y * np.log(p) + (1 - y) * np.log(1 - p))
    return total / len(X)

# %%
def accuracy(theta, X, Y):
    correct = 0
    for x, y in zip(X, Y):
        pred = 1 if forward(theta, x) > 0.5 else 0
        correct += int(pred == y)
    return correct / len(X)

# %% [markdown]
# Training loop (single restart) + multi-restart driver

# %%
epochs = 60               # number of gradient-descent steps per restart
LOSS_ZERO_THRESHOLD = 1e-2 # loss below this (AND 100% accuracy) = "converged

def train_once(seed):
    rng = np.random.default_rng(seed)

    # Initialize parameters as small random values (0.8 * standard normal)
    # rather than zeros, since all-zero rotations would start the circuit in
    # a symmetric state with vanishing/uninformative gradients.

    theta = np.array(0.8 * rng.standard_normal((n_layers, n_qubits, 2)), requires_grad=True)

    # Adam optimizer: adapts the learning rate per-parameter, generally
    # converges faster and more reliably than plain gradient descent here

    opt = qml.AdamOptimizer(stepsize=0.2)
    loss_history = []
    acc_history = []
    converged_epoch = None
    for epoch in range(1, epochs + 1):
        # One optimization step: PennyLane computes the gradient of bce_loss
        # w.r.t. theta (via the parameter-shift rule under the hood) and
        # updates theta accordingly.
        theta = opt.step(lambda t: bce_loss(t, X_data, Y_data), theta)
        loss = bce_loss(theta, X_data, Y_data)
        acc = accuracy(theta, X_data, Y_data)
        loss_history.append(float(loss))
        acc_history.append(acc)
        if converged_epoch is None and loss < LOSS_ZERO_THRESHOLD and acc == 1.0:
            converged_epoch = epoch
    return theta, loss_history, acc_history, converged_epoch

# %%
# MULTI-RESTART TRAINING:
# Variational circuits can get stuck in different local minima depending on
# their random initialization. Running several restarts (different seeds) and
# keeping the best one is standard practice to avoid reporting an unlucky run.

print(" Parametric quantum circuit for Movie Preference (SciFi vs Romance)")
print("=" * 70)

best_theta, best_loss_hist, best_acc_hist, best_converged = None, None, None, None
best_final_loss = np.inf

for seed in range(2):
    theta, loss_hist, acc_hist, converged_epoch = train_once(seed)
    final_loss = loss_hist[-1]
    conv_str = str(converged_epoch) if converged_epoch else "not reached"
    print(f"restart {seed} | final loss = {final_loss:.4f} | "
          f"100% accuracy + near-zero loss first reached at epoch: {conv_str}")
    if final_loss < best_final_loss:
        best_final_loss = final_loss
        best_theta = theta
        best_loss_hist = loss_hist
        best_acc_hist = acc_hist
        best_converged = converged_epoch

# Keep only the best-performing restart's parameters for everything that follows.

theta = best_theta
print(f"\nBest restart final loss: {best_final_loss:.4f}")
if best_converged:
    print(f"Best restart reached 100% precision/recall (all 11 predictions correct) "
          f"and near-zero loss at epoch {best_converged} (out of {epochs}).")
else:
    print("Best restart did not reach the zero-loss threshold within the epoch budget.")
# Out:
#  Parametric quantum circuit for Movie Preference (SciFi vs Romance)
# ======================================================================
# restart 0 | final loss = 0.2908 | 100% accuracy + near-zero loss first reached at epoch: not reached
# restart 1 | final loss = 0.2028 | 100% accuracy + near-zero loss first reached at epoch: not reached
#
# Best restart final loss: 0.2028
# Best restart did not reach the zero-loss threshold within the epoch budget.

# %% [markdown]
# Final truth table — inspect exactly what the model predicts per user

# %%
print("\nFinal predictions:")
print("-" * 70)
print(f"{'UserID':>6} | {'target':>8} | {'p(Romance)':>11} | {'predicted':>9}")
print("-" * 70)
correct = 0
for i, (x, y) in enumerate(zip(X_data, Y_data)):
    p = forward(theta, x)
    pred = 1 if p > 0.5 else 0
    correct += int(pred == y)
    true_name = "Romance" if y == 1 else "SciFi"
    pred_name = "Romance" if pred == 1 else "SciFi"
    print(f"{i:6d} | {true_name:>8} | {p:>11.4f} | {pred_name:>9}")
print("-" * 70)
print(f"Accuracy: {correct}/{len(Y_data)}")
# Out:
# Final predictions:
# ----------------------------------------------------------------------
# UserID |   target |  p(Romance) | predicted
# ----------------------------------------------------------------------
#      0 |    SciFi |      0.1935 |     SciFi
#      1 |    SciFi |      0.1745 |     SciFi
#      2 |  Romance |      0.8912 |   Romance
#      3 |  Romance |      0.8912 |   Romance
#      4 |  Romance |      0.8912 |   Romance
#      5 |    SciFi |      0.2041 |     SciFi
#      6 |  Romance |      0.8113 |   Romance
#      7 |    SciFi |      0.1935 |     SciFi
#      8 |  Romance |      0.7304 |   Romance
#      9 |  Romance |      0.6324 |   Romance
#     10 |  Romance |      0.7046 |   Romance
#     11 |    SciFi |      0.1495 |     SciFi
#     12 |  Romance |      0.7384 |   Romance
#     13 |  Romance |      0.7046 |   Romance
#     14 |    SciFi |      0.0564 |     SciFi
#     15 |  Romance |      0.7304 |   Romance
#     16 |  Romance |      0.7046 |   Romance
#     17 |  Romance |      0.7046 |   Romance
#     18 |  Romance |      0.8608 |   Romance
#     19 |  Romance |      0.8113 |   Romance
#     20 |    SciFi |      0.1495 |     SciFi
#     21 |    SciFi |      0.0336 |     SciFi
#     22 |  Romance |      0.8154 |   Romance
#     23 |    SciFi |      0.1935 |     SciFi
#     24 |  Romance |      0.8743 |   Romance
#     25 |    SciFi |      0.2041 |     SciFi
#     26 |  Romance |      0.9354 |   Romance
#     27 |  Romance |      0.8262 |   Romance
#     28 |    SciFi |      0.1935 |     SciFi
#     29 |    SciFi |      0.2305 |     SciFi
#     30 |    SciFi |      0.1495 |     SciFi
#     31 |  Romance |      0.8262 |   Romance
#     32 |  Romance |      0.8234 |   Romance
#     33 |    SciFi |      0.0285 |     SciFi
#     34 |    SciFi |      0.0336 |     SciFi
#     35 |    SciFi |      0.2147 |     SciFi
#     36 |    SciFi |      0.2928 |     SciFi
#     37 |    SciFi |      0.1745 |     SciFi
#     38 |    SciFi |      0.2305 |     SciFi
#     39 |  Romance |      0.9691 |   Romance
#     40 |  Romance |      0.6959 |   Romance
#     41 |  Romance |      0.8608 |   Romance
#     42 |    SciFi |      0.0285 |     SciFi
#     43 |  Romance |      0.6959 |   Romance
#     44 |    SciFi |      0.0336 |     SciFi
#     45 |    SciFi |      0.2928 |     SciFi
#     46 |    SciFi |      0.2041 |     SciFi
#     47 |  Romance |      0.8912 |   Romance
#     48 |    SciFi |      0.1727 |     SciFi
#     49 |  Romance |      0.8912 |   Romance
#     50 |  Romance |      0.8743 |   Romance
#     51 |    SciFi |      0.1005 |     SciFi
#     52 |  Romance |      0.8912 |   Romance
#     53 |  Romance |      0.9691 |   Romance
#     54 |    SciFi |      0.3050 |     SciFi
#     55 |  Romance |      0.7384 |   Romance
#     56 |    SciFi |      0.2147 |     SciFi
#     57 |    SciFi |      0.2928 |     SciFi
#     58 |    SciFi |      0.1745 |     SciFi
#     59 |    SciFi |      0.2041 |     SciFi
# ----------------------------------------------------------------------
# Accuracy: 60/60

# %% [markdown]
# Plot — loss (log scale) & accuracy vs epoch, for the best restart

# %%
# Log scale on the loss axis makes it easy to see relative improvement even
# once the loss gets small (a drop from 0.5 -> 0.2 looks as visually
# significant as 0.05 -> 0.02, which a linear axis would compress/hide).

fig, ax1 = plt.subplots(figsize=(8, 5))
epochs_range = range(1, epochs + 1)

ax1.plot(epochs_range, best_loss_hist, color="#d62728", linewidth=2, label="BCE loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Binary cross-entropy loss", color="#d62728")
ax1.tick_params(axis="y", labelcolor="#d62728")
ax1.set_yscale("log")

ax2 = ax1.twinx()         # second y-axis sharing the same x-axis, for accuracy
ax2.plot(epochs_range, best_acc_hist, color="#1f77b4", linewidth=2, linestyle="--", label="Accuracy")
ax2.set_ylabel("Accuracy on 11 users", color="#1f77b4")
ax2.tick_params(axis="y", labelcolor="#1f77b4")
ax2.set_ylim(-0.05, 1.05)

# Mark the convergence point, if the strict threshold was ever reached.

if best_converged:
    ax1.axvline(best_converged, color="gray", linestyle=":", linewidth=1.5)
    ax1.text(best_converged + 1, best_loss_hist[0] * 0.5,
              f"converged @ epoch {best_converged}", fontsize=9, color="gray")

plt.title("Movie Preference VQC training: loss and accuracy vs epoch (best restart)")
fig.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/loss_curve.png", dpi=150)
plt.show()

# %%
# We draw the circuit "for User 0" purely to have concrete numeric encoding
# angles to display — the CIRCUIT STRUCTURE (gates/entanglement) is identical
# for every user; only the encoding angles (x) change per user, while theta
# (the trained weights, already fixed after training) stays the same.

print("\nText-based circuit diagram (qml.draw), shown for User 0:")
print(qml.draw(circuit)(theta, X_data[0]))

print("\n" + "-" * 70)          #for separating diagram and image of circuit
print()

fig2, ax = qml.draw_mpl(circuit, decimals=2, style="pennylane")(theta, X_data[0])
fig2.suptitle("Trained Movie Preference variational circuit (shown for User 0)")
fig2.savefig(f"{OUTPUT_DIR}/circuit_diagram.png", dpi=150, bbox_inches="tight")
plt.show()

print(f"\nSaved loss curve to {OUTPUT_DIR}/loss_curve.png")
print(f"Saved circuit diagram to {OUTPUT_DIR}/circuit_diagram.png")
# Out:
# Text-based circuit diagram (qml.draw), shown for User 0:
# 0: ──RY(3.14)──RY(-0.95)──RZ(-0.05)─╭●───────╭X──RY(3.14)──RY(0.29)───RZ(0.24)──╭●───────╭X─┤  <Z>
# 1: ──RY(2.36)──RY(2.70)───RZ(-2.71)─╰X─╭●────│───RY(2.36)──RY(-0.45)──RZ(0.44)──╰X─╭●────│──┤
# 2: ──RY(0.00)──RY(1.45)───RZ(-1.59)────╰X─╭●─│───RY(0.00)──RY(-1.83)──RZ(-0.13)────╰X─╭●─│──┤
# 3: ──RY(0.00)──RY(1.35)───RZ(-1.57)───────╰X─╰●──RY(0.00)──RY(0.44)───RZ(0.48)────────╰X─╰●─┤
#
# ----------------------------------------------------------------------
# Saved loss curve to outputs/loss_curve.png
# Saved circuit diagram to outputs/circuit_diagram.png
